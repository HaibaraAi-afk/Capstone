# %%
import pandas as pd

# %%
df = pd.read_csv("Dataset/converted_data.csv")

# %%
df.head()
# Out:
#          Income  Age  Dependents     Occupation City_Tier         Bills  \
# 0  8.352969e+06   49           0  Self_Employed    Tier_1  2.918791e+06
# 1  5.026049e+06   34           2        Retired    Tier_2  1.167924e+06
# 2  9.425290e+06   35           1        Student    Tier_3  2.688879e+06
# 3  1.898539e+07   21           0  Self_Employed    Tier_3  5.037016e+06
# 4  4.654912e+06   52           4   Professional    Tier_2  1.632442e+06
#
#    Bills_Percentage     Groceries  Groceries_Percentage     Transport  ...  \
# 0         34.943159  1.555157e+06             18.618016  4.934563e+05  ...
# 1         23.237409  6.489336e+05             12.911406  2.887451e+05  ...
# 2         28.528345  1.464673e+06             15.539823  6.028199e+05  ...
# 3         26.531014  3.692149e+06             19.447323  1.329770e+06  ...
# 4         35.069242  6.974629e+05             14.983374  2.388069e+05  ...
#
#    Entertainment  Entertainment_Percentage     Healthcare  \
# ...
